// %%
var openDigger = require('../src/open_digger');
var year=2018

// %%
var query = openDigger.driver.clickhouse.query;
query(    `SHOW DATABASES`).then(res=>{    console.log(res);})
// Out:
// [
//   { name: '_temporary_and_external_tables' },
//   { name: 'default' },
//   { name: 'github_log' },
//   { name: 'system' }
// ]

// %%
query(    `SHOW TABLES from github_log`).then(res=>{    console.log(res);})
// Out:
// [
//   { name: 'year2015' },
//   { name: 'year2016' },
//   { name: 'year2017' },
//   { name: 'year2018' },
//   { name: 'year2019' },
//   { name: 'year2020' },
//   { name: 'year2021' },
//   { name: 'year2022' }
// ]

// %%
query(   
`
    select *  
from github_log.year${year} 
where repo_name='angular/angular.js'
`) .then(res=>{    console.log(res);});
// Out:
// [
//   {
//     id: '8304183371',
//     type: 'CommitCommentEvent',
//     action: '',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-21 20:13:03',
//     created_date: '2018-09-21',
//     issue_id: '0',
//     issue_number: 0,
//     issue_title: '',
//     issue_body: '',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '0',
//     issue_author_login: '',
//     issue_author_type: '',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '1970-01-01 00:00:00',
//     issue_updated_at: '1970-01-01 00:00:00',
//     issue_comments: 0,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '0',
//     issue_comment_body: '',
//     issue_comment_created_at: '1970-01-01 00:00:00',
//     issue_comment_updated_at: '1970-01-01 00:00:00',
//     issue_comment_author_association: '',
//     issue_comment_author_id: '0',
//     issue_comment_author_login: '',
//     issue_comment_author_type: '',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '30596928',
//     commit_comment_author_id: '15655',
//     commit_comment_author_login: 'petebacondarwin',
//     commit_comment_author_type: 'User',
//     commit_comment_author_association: 'MEMBER',
//     commit_comment_body: 'Sorry!',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '2018-09-21 20:13:03',
//     commit_comment_updated_at: '2018-09-21 20:13:03'
//   },
//   {
//     id: '8229473142',
//     type: 'CreateEvent',
//     action: '',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-07 09:29:54',
//     created_date: '2018-09-07',
//     issue_id: '0',
//     issue_number: 0,
//     issue_title: '',
//     issue_body: '',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '0',
//     issue_author_login: '',
//     issue_author_type: '',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '1970-01-01 00:00:00',
//     issue_updated_at: '1970-01-01 00:00:00',
//     issue_comments: 0,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '0',
//     issue_comment_body: '',
//     issue_comment_created_at: '1970-01-01 00:00:00',
//     issue_comment_updated_at: '1970-01-01 00:00:00',
//     issue_comment_author_association: '',
//     issue_comment_author_id: '0',
//     issue_comment_author_login: '',
//     issue_comment_author_type: '',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: 'v1.7.4',
//     create_ref_type: 'tag',
//     create_master_branch: 'master',
//     create_description: 'AngularJS - HTML enhanced for web apps!',
//     create_pusher_type: 'user',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8209316936',
//     type: 'IssueCommentEvent',
//     action: 'created',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-04 07:08:42',
//     created_date: '2018-09-04',
//     issue_id: '18221749',
//     issue_number: 3651,
//     issue_title: '$location.path("/mypath") is not refreshing the page ',
//     issue_body: 'Hi guys, \n' +
//       'I am having problem with $location.path("/mypath"). The page of which is redirected is not refreshed, I need to press F5 for getting the page refreshed. Anyone has passed for this? Here the code:\n' +
//       '\n' +
//       '$scope.registerUser = function(){\n' +
//       '        var u = new User();\n' +
//       '        u.name = $scope.user.name;\n' +
//       '        u.email = $scope.user.email;\n' +
//       '        u.$save();\n' +
//       '        $location.path("/topmovie");\n' +
//       '\n' +
//       '```\n' +
//       '};\n' +
//       '```\n' +
//       '\n' +
//       'The app example is [here](https://github.com/camilolopes/workspaceAngularJs/tree/master/movie-vote/src/main/webapp/js/controller)\n',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '1547808',
//     issue_author_login: 'camilolopes',
//     issue_author_type: 'User',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '2013-08-19 03:50:48',
//     issue_updated_at: '2018-09-04 07:08:38',
//     issue_comments: 3,
//     issue_closed_at: '2013-08-20 06:11:48',
//     issue_comment_id: '418263809',
//     issue_comment_body: '@okmman if you can provide a reproduction to show that it is a regression then please open a new issue.',
//     issue_comment_created_at: '2018-09-04 07:08:38',
//     issue_comment_updated_at: '2018-09-04 07:08:38',
//     issue_comment_author_association: 'MEMBER',
//     issue_comment_author_id: '15655',
//     issue_comment_author_login: 'petebacondarwin',
//     issue_comment_author_type: 'User',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8210403807',
//     type: 'IssueCommentEvent',
//     action: 'created',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-04 10:36:59',
//     created_date: '2018-09-04',
//     issue_id: '108289566',
//     issue_number: 12942,
//     issue_title: 'Add an `$assign` method to Scope',
//     issue_body: "It's known that Scope has a method `$eval` which returns expression value based on that scope;\n" +
//       'But when we want to assign a value on Scope by string when using something like "life.meanning",\n' +
//       'we should write this:\n' +
//       "`$parse('life.meanning').assign(scope,42)`\n" +
//       "it's a little bit boring\n" +
//       'It would it be very convenient if there is a method called $assign:\n' +
//       "`$scope.$assign('life.meanning',42)`\n",
//     'issue_labels.name': [ 'component: scopes', 'resolution: not core', 'type: feature' ],
//     'issue_labels.color': [ 'fbca04', '5319e7', '00a606' ],
//     'issue_labels.default': [ 0, 0, 0 ],
//     'issue_labels.description': [ '', '', '' ],
//     issue_author_id: '2993947',
//     issue_author_login: 'xieranmaya',
//     issue_author_type: 'User',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '2015-09-25 09:10:34',
//     issue_updated_at: '2018-09-04 10:36:59',
//     issue_comments: 9,
//     issue_closed_at: '2015-10-03 09:23:29',
//     issue_comment_id: '418320205',
//     issue_comment_body: '@pankajkachhwaye  - `$assign` is not actually a thing. Did you implement it yourself?',
//     issue_comment_created_at: '2018-09-04 10:36:59',
//     issue_comment_updated_at: '2018-09-04 10:36:59',
//     issue_comment_author_association: 'MEMBER',
//     issue_comment_author_id: '15655',
//     issue_comment_author_login: 'petebacondarwin',
//     issue_comment_author_type: 'User',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8287220184',
//     type: 'IssueCommentEvent',
//     action: 'created',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-19 08:13:12',
//     created_date: '2018-09-19',
//     issue_id: '360880057',
//     issue_number: 16696,
//     issue_title: 'Latest versions not available on CDN',
//     issue_body: "I'm submitting a ...\r\n" +
//       '\r\n' +
//       '- [x] bug report\r\n' +
//       '- [x] feature request\r\n' +
//       '- [ ] other\r\n' +
//       '\r\n' +
//       '**Current behavior:**\r\n' +
//       'The latest versions of AngularJS, 1.7.3 and 1.7.4, are unavailable on Google and CDNJS CDN.\r\n' +
//       '\r\n' +
//       '**Expected / new behavior:**\r\n' +
//       'The latest versions of AngularJS, 1.7.3 and 1.7.4, should be available on CDN.\r\n' +
//       '\r\n' +
//       '**Minimal reproduction of the problem with instructions:**\r\n' +
//       'Visiting these URLs results in a 404:\r\n' +
//       'https://ajax.googleapis.com/ajax/libs/angularjs/1.7.3/angular.min.js\r\n' +
//       'https://ajax.googleapis.com/ajax/libs/angularjs/1.7.4/angular.min.js\r\n' +
//       '\r\n' +
//       'The listing on CDNJS also does not have the latest versions available when visiting this page:\r\n' +
//       'https://cdnjs.com/libraries/angular.js/\r\n' +
//       '\r\n' +
//       '**AngularJS version:** 1.7.3 - 1.7.4\r\n' +
//       '\r\n' +
//       '**Browser:** all',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '9417091',
//     issue_author_login: 'wolfet',
//     issue_author_type: 'User',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '2018-09-17 13:53:15',
//     issue_updated_at: '2018-09-19 08:13:10',
//     issue_comments: 3,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '422702822',
//     issue_comment_body: 'We have Googlers working on getting the releases onto the Google CDN.',
//     issue_comment_created_at: '2018-09-19 08:13:10',
//     issue_comment_updated_at: '2018-09-19 08:13:10',
//     issue_comment_author_association: 'MEMBER',
//     issue_comment_author_id: '15655',
//     issue_comment_author_login: 'petebacondarwin',
//     issue_comment_author_type: 'User',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8293725538',
//     type: 'IssueCommentEvent',
//     action: 'created',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-20 07:43:33',
//     created_date: '2018-09-20',
//     issue_id: '362021445',
//     issue_number: 16701,
//     issue_title: 'Hi, I added some third party libraries in iOS and Android but that library was coming under MIT Licence can i add Library in my project or i want to pay anything to MIT LIicence or is it free.',
//     issue_body: '<!--\r\n' +
//       "IF YOU DON'T FILL OUT THE FOLLOWING INFORMATION WE MIGHT CLOSE YOUR ISSUE WITHOUT INVESTIGATION\r\n" +
//       '-->\r\n' +
//       '\r\n' +
//       '<!--\r\n' +
//       '- For *SUPPORT QUESTIONS*, use one of the\r\n' +
//       '[support channels](https://github.com/angular/angular.js/blob/master/CONTRIBUTING.md#question).\r\n' +
//       '- Before submitting, please **SEARCH GITHUB** for a similar issue or PR. -->\r\n' +
//       '\r\n' +
//       "**I'm submitting a ...**\r\n" +
//       '<!-- (check one with "x") -->\r\n' +
//       '- [ ] bug report\r\n' +
//       '- [ ] feature request\r\n' +
//       '- [x] other <!--(Please do not submit support requests here - see above)-->\r\n' +
//       '\r\n' +
//       '**Current behavior:**\r\n' +
//       '<!-- Describe how the bug manifests / how the current features are insufficient. -->\r\n' +
//       '\r\n' +
//       '**Expected / new behavior:**\r\n' +
//       '<!-- Describe what the behavior would be without the bug / how the feature would improve AngularJS -->\r\n' +
//       '\r\n' +
//       '**Minimal reproduction of the problem with instructions:**\r\n' +
//       '<!--\r\n' +
//       'If the current behavior is a bug or you can illustrate your feature request better with an example,\r\n' +
//       'please provide the *STEPS TO REPRODUCE* and if possible a *MINIMAL DEMO* of the problem via\r\n' +
//       'https://plnkr.co or similar (you can use this template as a starting point: http://plnkr.co/edit/tpl:yBpEi4).\r\n' +
//       '-->\r\n' +
//       '\r\n' +
//       '**AngularJS version:** 1.x.y\r\n' +
//       '<!-- Check whether this is still an issue in the most recent stable or in the snapshot AngularJS\r\n' +
//       'version (https://code.angularjs.org/snapshot/) -->\r\n' +
//       '\r\n' +
//       '**Browser:** [all | Chrome XX | Firefox XX | Edge XX | IE XX | Safari XX | Mobile Chrome XX | Android X.X Web Browser | iOS XX Safari | iOS XX UIWebView | iOS XX WKWebView ]\r\n' +
//       '<!-- All browsers where this could be reproduced (and Operating System if relevant) -->\r\n' +
//       '\r\n' +
//       '**Anything else:**\r\n' +
//       '<!-- e.g. stacktraces, related issues, suggestions how to fix -->\r\n',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '32352462',
//     issue_author_login: 'SravanZetamp',
//     issue_author_type: 'User',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '2018-09-20 05:13:55',
//     issue_updated_at: '2018-09-20 07:43:33',
//     issue_comments: 0,
//     issue_closed_at: '2018-09-20 07:43:33',
//     issue_comment_id: '423075997',
//     issue_comment_body: '@SravanZetamp - you can see the MIT license here https://github.com/angular/angular.js/blob/master/LICENSE. GitHub also kindly adds some summary information about its use.\r\n' +
//       '\r\n' +
//       "tl;dr you don't have to pay for MIT licensed software.",
//     issue_comment_created_at: '2018-09-20 07:43:33',
//     issue_comment_updated_at: '2018-09-20 07:43:33',
//     issue_comment_author_association: 'MEMBER',
//     issue_comment_author_id: '15655',
//     issue_comment_author_login: 'petebacondarwin',
//     issue_comment_author_type: 'User',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8313448533',
//     type: 'IssueCommentEvent',
//     action: 'created',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-24 19:39:52',
//     created_date: '2018-09-24',
//     issue_id: '360880057',
//     issue_number: 16696,
//     issue_title: 'Latest versions not available on CDN',
//     issue_body: "I'm submitting a ...\r\n" +
//       '\r\n' +
//       '- [x] bug report\r\n' +
//       '- [x] feature request\r\n' +
//       '- [ ] other\r\n' +
//       '\r\n' +
//       '**Current behavior:**\r\n' +
//       'The latest versions of AngularJS, 1.7.3 and 1.7.4, are unavailable on Google and CDNJS CDN.\r\n' +
//       '\r\n' +
//       '**Expected / new behavior:**\r\n' +
//       'The latest versions of AngularJS, 1.7.3 and 1.7.4, should be available on CDN.\r\n' +
//       '\r\n' +
//       '**Minimal reproduction of the problem with instructions:**\r\n' +
//       'Visiting these URLs results in a 404:\r\n' +
//       'https://ajax.googleapis.com/ajax/libs/angularjs/1.7.3/angular.min.js\r\n' +
//       'https://ajax.googleapis.com/ajax/libs/angularjs/1.7.4/angular.min.js\r\n' +
//       '\r\n' +
//       'The listing on CDNJS also does not have the latest versions available when visiting this page:\r\n' +
//       'https://cdnjs.com/libraries/angular.js/\r\n' +
//       '\r\n' +
//       '**AngularJS version:** 1.7.3 - 1.7.4\r\n' +
//       '\r\n' +
//       '**Browser:** all',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '9417091',
//     issue_author_login: 'wolfet',
//     issue_author_type: 'User',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '2018-09-17 13:53:15',
//     issue_updated_at: '2018-09-24 19:39:51',
//     issue_comments: 4,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '424099177',
//     issue_comment_body: 'hmm, the versions here are correct:\r\n' +
//       '*  https://code.angularjs.org/1.7.3/angular.min.js\r\n' +
//       '*  https://code.angularjs.org/1.7.4/angular.min.js',
//     issue_comment_created_at: '2018-09-24 19:39:51',
//     issue_comment_updated_at: '2018-09-24 19:39:51',
//     issue_comment_author_association: 'MEMBER',
//     issue_comment_author_id: '15655',
//     issue_comment_author_login: 'petebacondarwin',
//     issue_comment_author_type: 'User',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8316842439',
//     type: 'IssueCommentEvent',
//     action: 'created',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-25 10:12:03',
//     created_date: '2018-09-25',
//     issue_id: '336294967',
//     issue_number: 16616,
//     issue_title: 'ngAnimateSwap is not compatible with ngIf',
//     issue_body: '<!--\r\n' +
//       "IF YOU DON'T FILL OUT THE FOLLOWING INFORMATION WE MIGHT CLOSE YOUR ISSUE WITHOUT INVESTIGATION\r\n" +
//       '-->\r\n' +
//       '\r\n' +
//       '<!--\r\n' +
//       '- For *SUPPORT QUESTIONS*, use one of the\r\n' +
//       '[support channels](https://github.com/angular/angular.js/blob/master/CONTRIBUTING.md#question).\r\n' +
//       '- Before submitting, please **SEARCH GITHUB** for a similar issue or PR. -->\r\n' +
//       '\r\n' +
//       "**I'm submitting a ...**\r\n" +
//       '<!-- (check one with "x") -->\r\n' +
//       '- [x] bug report\r\n' +
//       '- [ ] feature request\r\n' +
//       '- [ ] other <!--(Please do not submit support requests here - see above)-->\r\n' +
//       '\r\n' +
//       '**Current behavior:**\r\n' +
//       '<!-- Describe how the bug manifests / how the current features are insufficient. -->\r\n' +
//       'ngAnimateSwap registers a comment of the element, not the element itself, so if an element contains the `ng-if` attribute, `ng-animate-swap` will not work.\r\n' +
//       '\r\n' +
//       '**Expected / new behavior:**\r\n' +
//       '<!-- Describe what the behavior would be without the bug / how the feature would improve AngularJS -->\r\n' +
//       "Having a conditional element also be animated if it's visible.\r\n" +
//       '\r\n' +
//       '**Minimal reproduction of the problem with instructions:**\r\n' +
//       '<!--\r\n' +
//       'If the current behavior is a bug or you can illustrate your feature request better with an example,\r\n' +
//       'please provide the *STEPS TO REPRODUCE* and if possible a *MINIMAL DEMO* of the problem via\r\n' +
//       'https://plnkr.co or similar (you can use this template as a starting point: http://plnkr.co/edit/tpl:yBpEi4).\r\n' +
//       '-->\r\n' +
//       '\r\n' +
//       '1. Have an element with both `ng-animate-swap` and `ng-if`\r\n' +
//       '2. The element will always be invisible, as it swaps the comments.\r\n' +
//       '\r\n' +
//       'https://codepen.io/anon/pen/LrgBwY\r\n' +
//       '\r\n' +
//       '**AngularJS version:** 1.7.2\r\n' +
//       '<!-- Check whether this is still an issue in the most recent stable or in the snapshot AngularJS\r\n' +
//       'version (https://code.angularjs.org/snapshot/) -->\r\n' +
//       '\r\n' +
//       '**Browser:** [all]\r\n' +
//       '<!-- All browsers where this could be reproduced (and Operating System if relevant) -->\r\n' +
//       '(tested on FF 62, OSX High Seirra )\r\n',
//     'issue_labels.name': [ 'component: ngAnimate', 'needs: investigation', 'type: bug' ],
//     'issue_labels.color': [ 'bfdadc', '444444', '000000' ],
//     'issue_labels.default': [ 0, 0, 0 ],
//     'issue_labels.description': [ '', '', '' ],
//     issue_author_id: '3892772',
//     issue_author_login: 'bersLucas',
//     issue_author_type: 'User',
//     issue_author_association: '',
//     issue_assignee_id: '8604205',
//     issue_assignee_login: 'gkalpak',
//     'issue_assignees.login': [ 'gkalpak' ],
//     'issue_assignees.id': [ '8604205' ],
//     issue_created_at: '2018-06-27 16:09:59',
//     issue_updated_at: '2018-09-25 10:12:03',
//     issue_comments: 3,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '424284966',
//     issue_comment_body: "The reason that this has been moved to `1.7.x - won't fix` is that we are now in LTS mode, which means that we are only fixing security and other significant bugs. But what @gkalpak  is referring to, is that we are considering one more bug fix release, which may contain some issues from this milestone.",
//     issue_comment_created_at: '2018-09-25 10:12:03',
//     issue_comment_updated_at: '2018-09-25 10:12:03',
//     issue_comment_author_association: 'MEMBER',
//     issue_comment_author_id: '15655',
//     issue_comment_author_login: 'petebacondarwin',
//     issue_comment_author_type: 'User',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8338520588',
//     type: 'IssueCommentEvent',
//     action: 'created',
//     actor_id: '15655',
//     actor_login: 'petebacondarwin',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-28 14:32:00',
//     created_date: '2018-09-28',
//     issue_id: '364823323',
//     issue_number: 16705,
//     issue_title: 'ng-change triggered at init with step and invalid value',
//     issue_body: "**I'm submitting a ...**\r\n" +
//       '- [x] bug report\r\n' +
//       '- [ ] feature request\r\n' +
//       '- [ ] other\r\n' +
//       '\r\n' +
//       '**Current behavior:**\r\n' +
//       'When using the combinaison of :\r\n' +
//       '- input type="number"\r\n' +
//       '- ng-change\r\n' +
//       '- step\r\n' +
//       '- ng-model with a value not multiple to the step (thus an invalid value).\r\n' +
//       '\r\n' +
//       "Then the ng-change is triggered, even if the value didn't change.\r\n" +
//       '\r\n' +
//       '**Expected / new behavior:**\r\n' +
//       "The ng-change event shouldn't be triggered because the value didn't change (even if it's invalid), neither by the user or programmatically.\r\n" +
//       '\r\n' +
//       '**Minimal reproduction of the problem with instructions:**\r\n' +
//       '<input type="number" ng-model="order.amount" ng-change="amountChanged(order)" step="500">\r\n' +
//       'If the value of order.amount equals 500.01, then the function amountChanged is called.\r\n' +
//       '\r\n' +
//       '**AngularJS version:** 1.7.4\r\n' +
//       '\r\n' +
//       '**Browser:** [all]\r\n' +
//       'Tested with Chrome 69 and Firefox 62.\r\n' +
//       '\r\n' +
//       '**Anything else:**\r\n' +
//       'N/A',
//     'issue_labels.name': [ 'needs: more info' ],
//     'issue_labels.color': [ 'd7eb9f' ],
//     'issue_labels.default': [ 0 ],
//     'issue_labels.description': [ '' ],
//     issue_author_id: '43670124',
//     issue_author_login: 'NeelLargeronGroupeEram',
//     issue_author_type: 'User',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '2018-09-28 10:03:13',
//     issue_updated_at: '2018-09-28 14:31:59',
//     issue_comments: 2,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '425454794',
//     issue_comment_body: 'I believe that this is working as expected. When the input is invalid, its value is set to `undefined` thus triggering `ng-change`.',
//     issue_comment_created_at: '2018-09-28 14:31:59',
//     issue_comment_updated_at: '2018-09-28 14:31:59',
//     issue_comment_author_association: 'MEMBER',
//     issue_comment_author_id: '15655',
//     issue_comment_author_login: 'petebacondarwin',
//     issue_comment_author_type: 'User',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
// ...
//     issue_comment_author_association: '',
//     issue_comment_author_id: '0',
//     issue_comment_author_login: '',
//     issue_comment_author_type: '',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8273207292',
//     type: 'WatchEvent',
//     action: 'started',
//     actor_id: '2619120',
//     actor_login: 'apaulro',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-17 04:02:59',
//     created_date: '2018-09-17',
//     issue_id: '0',
//     issue_number: 0,
//     issue_title: '',
//     issue_body: '',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '0',
//     issue_author_login: '',
//     issue_author_type: '',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '1970-01-01 00:00:00',
//     issue_updated_at: '1970-01-01 00:00:00',
//     issue_comments: 0,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '0',
//     issue_comment_body: '',
//     issue_comment_created_at: '1970-01-01 00:00:00',
//     issue_comment_updated_at: '1970-01-01 00:00:00',
//     issue_comment_author_association: '',
//     issue_comment_author_id: '0',
//     issue_comment_author_login: '',
//     issue_comment_author_type: '',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8201090032',
//     type: 'WatchEvent',
//     action: 'started',
//     actor_id: '2639229',
//     actor_login: 'csdenboer',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-01 13:32:34',
//     created_date: '2018-09-01',
//     issue_id: '0',
//     issue_number: 0,
//     issue_title: '',
//     issue_body: '',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '0',
//     issue_author_login: '',
//     issue_author_type: '',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '1970-01-01 00:00:00',
//     issue_updated_at: '1970-01-01 00:00:00',
//     issue_comments: 0,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '0',
//     issue_comment_body: '',
//     issue_comment_created_at: '1970-01-01 00:00:00',
//     issue_comment_updated_at: '1970-01-01 00:00:00',
//     issue_comment_author_association: '',
//     issue_comment_author_id: '0',
//     issue_comment_author_login: '',
//     issue_comment_author_type: '',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   {
//     id: '8290592510',
//     type: 'WatchEvent',
//     action: 'started',
//     actor_id: '2717801',
//     actor_login: 'marizmelo',
//     repo_id: '460078',
//     repo_name: 'angular/angular.js',
//     org_id: '139426',
//     org_login: 'angular',
//     created_at: '2018-09-19 17:50:42',
//     created_date: '2018-09-19',
//     issue_id: '0',
//     issue_number: 0,
//     issue_title: '',
//     issue_body: '',
//     'issue_labels.name': [],
//     'issue_labels.color': [],
//     'issue_labels.default': [],
//     'issue_labels.description': [],
//     issue_author_id: '0',
//     issue_author_login: '',
//     issue_author_type: '',
//     issue_author_association: '',
//     issue_assignee_id: '0',
//     issue_assignee_login: '',
//     'issue_assignees.login': [],
//     'issue_assignees.id': [],
//     issue_created_at: '1970-01-01 00:00:00',
//     issue_updated_at: '1970-01-01 00:00:00',
//     issue_comments: 0,
//     issue_closed_at: '1970-01-01 00:00:00',
//     issue_comment_id: '0',
//     issue_comment_body: '',
//     issue_comment_created_at: '1970-01-01 00:00:00',
//     issue_comment_updated_at: '1970-01-01 00:00:00',
//     issue_comment_author_association: '',
//     issue_comment_author_id: '0',
//     issue_comment_author_login: '',
//     issue_comment_author_type: '',
//     pull_commits: 0,
//     pull_additions: 0,
//     pull_deletions: 0,
//     pull_changed_files: 0,
//     pull_merged: 0,
//     pull_merge_commit_sha: '',
//     pull_merged_at: '1970-01-01 00:00:00',
//     pull_merged_by_id: '0',
//     pull_merged_by_login: '',
//     pull_merged_by_type: '',
//     pull_requested_reviewer_id: '0',
//     pull_requested_reviewer_login: '',
//     pull_requested_reviewer_type: '',
//     pull_review_comments: 0,
//     repo_description: '',
//     repo_size: 0,
//     repo_stargazers_count: 0,
//     repo_forks_count: 0,
//     repo_language: '',
//     repo_has_issues: 0,
//     repo_has_projects: 0,
//     repo_has_downloads: 0,
//     repo_has_wiki: 0,
//     repo_has_pages: 0,
//     repo_license: '',
//     repo_default_branch: '',
//     repo_created_at: '1970-01-01 00:00:00',
//     repo_updated_at: '1970-01-01 00:00:00',
//     repo_pushed_at: '1970-01-01 00:00:00',
//     pull_review_id: '0',
//     pull_review_comment_id: '0',
//     pull_review_comment_path: '',
//     pull_review_comment_position: '',
//     pull_review_comment_author_id: '0',
//     pull_review_comment_author_login: '',
//     pull_review_comment_author_type: '',
//     pull_review_comment_author_association: '',
//     pull_review_comment_body: '',
//     pull_review_comment_created_at: '1970-01-01 00:00:00',
//     pull_review_comment_updated_at: '1970-01-01 00:00:00',
//     push_id: '0',
//     push_size: 0,
//     push_distinct_size: 0,
//     push_ref: '',
//     push_head: '',
//     push_before: '',
//     'push_commits.name': [],
//     'push_commits.email': [],
//     'push_commits.message': [],
//     fork_forkee_id: '0',
//     fork_forkee_full_name: '',
//     fork_forkee_owner_id: '0',
//     fork_forkee_owner_login: '',
//     fork_forkee_owner_type: '',
//     delete_ref: '',
//     delete_ref_type: '',
//     delete_pusher_type: '',
//     create_ref: '',
//     create_ref_type: '',
//     create_master_branch: '',
//     create_description: '',
//     create_pusher_type: '',
//     'gollum_pages.page_name': [],
//     'gollum_pages.title': [],
//     'gollum_pages.action': [],
//     member_id: '0',
//     member_login: '',
//     member_type: '',
//     release_id: '0',
//     release_tag_name: '',
//     release_target_commitish: '',
//     release_name: '',
//     release_draft: 0,
//     release_author_id: '0',
//     release_author_login: '',
//     release_author_type: '',
//     release_prerelease: 0,
//     release_created_at: '1970-01-01 00:00:00',
//     release_published_at: '1970-01-01 00:00:00',
//     release_body: '',
//     'release_assets.name': [],
//     'release_assets.uploader_login': [],
//     'release_assets.uploader_id': [],
//     'release_assets.content_type': [],
//     'release_assets.state': [],
//     'release_assets.size': [],
//     'release_assets.download_count': [],
//     commit_comment_id: '0',
//     commit_comment_author_id: '0',
//     commit_comment_author_login: '',
//     commit_comment_author_type: '',
//     commit_comment_author_association: '',
//     commit_comment_body: '',
//     commit_comment_path: '',
//     commit_comment_position: '',
//     commit_comment_line: '',
//     commit_comment_created_at: '1970-01-01 00:00:00',
//     commit_comment_updated_at: '1970-01-01 00:00:00'
//   },
//   ... 9217 more items
// ]

// %%
// 第一题
query(
`
select toMonth(created_at) as month, max(repo_stargazers_count)as stars, max(repo_forks_count) as forks
from(
select created_at,repo_stargazers_count, repo_forks_count from github_log.year${year}
where repo_name = 'angular/angular.js'
and toYear(issue_created_at) = 2018
)group by month
`) .then(res=>{    console.log(res);});
// Out:
// [
//   { month: 1, stars: 57927, forks: 28767 },
//   { month: 2, stars: 58081, forks: 28820 },
//   { month: 3, stars: 58191, forks: 28869 },
//   { month: 4, stars: 58388, forks: 28919 },
//   { month: 5, stars: 58548, forks: 28936 },
//   { month: 6, stars: 58737, forks: 28962 },
//   { month: 7, stars: 58863, forks: 28972 },
//   { month: 8, stars: 58989, forks: 28983 },
//   { month: 9, stars: 59139, forks: 29024 },
//   { month: 10, stars: 59223, forks: 29032 },
//   { month: 11, stars: 59301, forks: 29017 },
//   { month: 12, stars: 59326, forks: 29017 }
// ]

// %%
// 第2题 每月打开的issue
query(
`
select toMonth(issue_created_at) as month, count(*) as openIssueCnt from(
select distinct issue_created_at from github_log.year${year}
where repo_name = 'angular/angular.js'
and toYear(issue_created_at) = 2018
)group by month
`
) .then(res=>{    console.log(res);});
// Out:
// [
//   { month: 1, openIssueCnt: '46' },
//   { month: 2, openIssueCnt: '43' },
//   { month: 3, openIssueCnt: '42' },
//   { month: 4, openIssueCnt: '25' },
//   { month: 5, openIssueCnt: '41' },
//   { month: 6, openIssueCnt: '35' },
//   { month: 7, openIssueCnt: '30' },
//   { month: 8, openIssueCnt: '28' },
//   { month: 9, openIssueCnt: '27' },
//   { month: 10, openIssueCnt: '32' },
//   { month: 11, openIssueCnt: '21' },
//   { month: 12, openIssueCnt: '23' }
// ]

// %%
// 第2题 每月关闭的issue
query(
`
select toMonth(issue_closed_at) as month, count(*) as closeIssueCnt from(
select distinct issue_closed_at from github_log.year${year}
where repo_name = 'angular/angular.js'
and toYear(issue_closed_at) = 2018
)group by month
`
) .then(res=>{    console.log(res);});
// Out:
// [
//   { month: 1, closeIssueCnt: '55' },
//   { month: 2, closeIssueCnt: '69' },
//   { month: 3, closeIssueCnt: '52' },
//   { month: 4, closeIssueCnt: '47' },
//   { month: 5, closeIssueCnt: '69' },
//   { month: 6, closeIssueCnt: '48' },
//   { month: 7, closeIssueCnt: '44' },
//   { month: 8, closeIssueCnt: '26' },
//   { month: 9, closeIssueCnt: '29' },
//   { month: 10, closeIssueCnt: '25' },
//   { month: 11, closeIssueCnt: '24' },
//   { month: 12, closeIssueCnt: '22' }
// ]

// %%
// 第三题
// 每月打开 PR个数

query(
`
select toMonth(created_at) as month, count(*) as openPrCnt from (
    select distinct created_at from github_log.year${year}
    where repo_name = 'angular/angular.js' 
    and type='PullRequestEvent'
    having toYear(created_at) = 2018
)
group by month
`
) .then(res=>{    console.log(res);});
// Out:
// [
//   { month: 1, openPrCnt: '51' },
//   { month: 2, openPrCnt: '44' },
//   { month: 3, openPrCnt: '39' },
//   { month: 4, openPrCnt: '30' },
//   { month: 5, openPrCnt: '46' },
//   { month: 6, openPrCnt: '43' },
//   { month: 7, openPrCnt: '41' },
//   { month: 8, openPrCnt: '18' },
//   { month: 9, openPrCnt: '23' },
//   { month: 10, openPrCnt: '26' },
//   { month: 11, openPrCnt: '31' },
//   { month: 12, openPrCnt: '22' }
// ]

// %%
// 第3题


// 每月pr合入个数
query(
`
select toMonth(pull_merged_at) as month , count(*) as prMergedCnt from github_log.year${year}
where repo_name = 'angular/angular.js' 
group by month
having toYear(pull_merged_at) =2018
`
) .then(res=>{    console.log(res);});
// Out:
// [
//   { month: 1, prMergedCnt: '18' },
//   { month: 2, prMergedCnt: '19' },
//   { month: 3, prMergedCnt: '9' },
//   { month: 4, prMergedCnt: '10' },
//   { month: 5, prMergedCnt: '10' },
//   { month: 6, prMergedCnt: '7' },
//   { month: 7, prMergedCnt: '7' },
//   { month: 8, prMergedCnt: '4' },
//   { month: 9, prMergedCnt: '4' },
//   { month: 10, prMergedCnt: '7' },
//   { month: 11, prMergedCnt: '3' },
//   { month: 12, prMergedCnt: '4' }
// ]

// %%
// 第4题

//活跃人数
query(
    
`
select month, count(*) as num from
(
select distinct toMonth(created_at) as month , actor_id from github_log.year${year}
where repo_name = 'angular/angular.js' 
)group by month

`
) .then(res=>{    console.log(res);});
// Out:
// [
//   { month: 1, num: '654' },
//   { month: 2, num: '537' },
//   { month: 3, num: '539' },
//   { month: 4, num: '546' },
//   { month: 5, num: '487' },
//   { month: 6, num: '546' },
//   { month: 7, num: '429' },
//   { month: 8, num: '450' },
//   { month: 9, num: '431' },
//   { month: 10, num: '372' },
//   { month: 11, num: '346' },
//   { month: 12, num: '278' }
// ]

// %%
// 第5题 Issue从打开到关闭的平均时长和中位数（单位：天）
//平均
query(
`
select toInt16(avg(day)) as average_day from(
select issue_id,abs(dateDiff('day', issue_created_at, issue_closed_at)) AS day from github_log.year${year}
where repo_name = 'angular/angular.js' 
group by issue_id,issue_created_at,issue_closed_at) 
`
) .then(res=>{    console.log(res);});

//中位数
query(
`
select toInt16(median(day)) as median_day from(
select issue_id,abs(dateDiff('day', issue_created_at, issue_closed_at)) AS day from github_log.year${year}
where repo_name = 'angular/angular.js' 
group by issue_id,issue_created_at,issue_closed_at) 
`
) .then(res=>{    console.log(res);});
// Out:
// [ { average_day: 7691 } ]
// [ { median_day: 1079 } ]

// %%
// 第6题
//平均时长
query(
`
select toInt16(avg(day)) as avg_day from
(select distinct issue_id,abs(dateDiff('day', pull_merged_at, created_at)) AS day from github_log.year${year}
where repo_name = 'angular/angular.js' 
and type = 'PullRequestEvent'
)

`
) .then(res=>{    console.log(res);});


//中位数
query(
`
select toInt16(median(day)) as median_day from
(select distinct issue_id,abs(dateDiff('day', pull_merged_at, created_at)) AS day from github_log.year${year}
where repo_name = 'angular/angular.js' 
and type = 'PullRequestEvent'
)

`
) .then(res=>{    console.log(res);});
// Out:
// [ { avg_day: 13336 } ]
// [ { median_day: 17627 } ]

// %%
// 第7题


// issue从打开到第一次有人回复（非本人回复）的平均时长
query(
    
`
select toInt16(avg(day)) as avg_day from
(
select issue_id,min(abs(dateDiff('day', issue_comment_created_at, issue_created_at))) as day  from github_log.year${year}
where repo_name = 'angular/angular.js' and issue_id != 0
group by issue_id
having toYear(issue_comment_created_at) != 1970
)
`
) .then(res=>{    console.log(res);});

// issue从打开到第一次有人回复（非本人回复）的中位数

query(
    
`
select toInt16(median(day)) as median_day from
(
select issue_id,min(abs(dateDiff('day', issue_comment_created_at, issue_created_at))) as day  from github_log.year${year}
where repo_name = 'angular/angular.js' and issue_id != 0
group by issue_id
having toYear(issue_comment_created_at) != 1970
)
`
) .then(res=>{    console.log(res);});
// Out:
// [ { avg_day: 534 } ]
// [ { median_day: 29 } ]

// %%
// 第7题


// pr从打开到第一次有人回复（非本人回复）的平均时长
query(
    
`
select toInt16(avg(day)) as avg_day from
(
select issue_id,min(abs(dateDiff('day', pull_review_comment_created_at, issue_created_at))) as day  from github_log.year${year}
where repo_name = 'angular/angular.js' and issue_id != 0
group by issue_id
having toYear(issue_comment_created_at) != 1970
)
`
) .then(res=>{    console.log(res);});

// pr从打开到第一次有人回复（非本人回复）的中位数

query(
    
`
select toInt16(median(day)) as median_day from
(
select issue_id,min(abs(dateDiff('day', pull_review_comment_created_at, issue_created_at))) as day  from github_log.year${year}
where repo_name = 'angular/angular.js' and issue_id != 0
group by issue_id
having toYear(issue_comment_created_at) != 1970
)
`
) .then(res=>{    console.log(res);});
// Out:
// [ { avg_day: 17140 } ]
// [ { median_day: 17534 } ]

// %% [markdown]
// AngularJS 首个版本于 2010 年由 Google 发布，2018 年 1 月官方宣布了淘汰 AngularJS 的时间表：在发布 1.7.0 之后，AngularJS 的开发将持续到 2018 年 6 月 30 日。
// 从数据中可以看到在2018年6月之后，项目的fork，pr，活跃人数等指标显著减少。
